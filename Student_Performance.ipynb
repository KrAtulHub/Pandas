# %%
import numpy as np 
import pandas as pd

# %%
df =pd.read_csv('student_performance.csv')

# %%
df.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A

# %%
df.shape
# Out:
# (1000000, 6)

# %%
df.head(10)
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
# 5           6                     13.4                   65.1
# 6           7                     26.1                   81.8
# 7           8                     20.4                  100.0
# 8           9                     11.7                  100.0
# 9          10                     18.8                   67.6
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A
# 5                  5.0         97.5     A
# 6                  5.9        100.0     A
# 7                  4.0         96.1     A
# 8                  8.2         69.8     C
# 9                  6.0         80.3     B

# %%
df.tail(10)
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 999990      999991                     15.4                   82.8
# 999991      999992                     30.0                   87.4
# 999992      999993                     26.3                   84.6
# 999993      999994                     20.7                   82.4
# 999994      999995                     15.1                   77.0
# 999995      999996                     18.0                   95.5
# 999996      999997                     15.7                   82.7
# 999997      999998                     14.2                   85.1
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade
# 999990                  4.0         86.9     A
# 999991                  6.7        100.0     A
# 999992                  4.5        100.0     A
# 999993                  5.5         99.1     A
# 999994                  9.2         80.5     B
# 999995                  4.8        100.0     A
# 999996                  6.7         88.3     A
# 999997                  5.8         87.9     A
# 999998                  5.3        100.0     A
# 999999                  4.1        100.0     A

# %%
df.columns
# Out:
# Index(['student_id', 'weekly_self_study_hours', 'attendance_percentage',
#        'class_participation', 'total_score', 'grade'],
#       dtype='object')

# %%
df['weekly_self_study_hours'].max()
# Out:
# 40.0

# %%
df[df['weekly_self_study_hours'] == df['weekly_self_study_hours'].max() ]
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 209            210                     40.0                   68.1
# 2895          2896                     40.0                   75.7
# 15843        15844                     40.0                   99.5
# 18851        18852                     40.0                   91.7
# 20126        20127                     40.0                   94.1
# ...            ...                      ...                    ...
# 971477      971478                     40.0                   74.2
# 973306      973307                     40.0                   90.0
# 974300      974301                     40.0                   78.8
# 976629      976630                     40.0                   93.9
# 980167      980168                     40.0                   82.6
#
#         class_participation  total_score grade
# 209                     6.7        100.0     A
# 2895                    4.2        100.0     A
# 15843                   8.0        100.0     A
# 18851                   7.0        100.0     A
# 20126                   3.0        100.0     A
# ...                     ...          ...   ...
# 971477                  7.7        100.0     A
# 973306                  6.2        100.0     A
# 974300                  2.5        100.0     A
# 976629                  7.0        100.0     A
# 980167                  7.2        100.0     A
#
# [166 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['student_id', 'weekly_self_study_hours', 'attendance_percentage',
#        'class_participation', 'total_score', 'grade'],
#       dtype='object')

# %%
df.sort_values('weekly_self_study_hours',ascending=False).head(5)
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 895979      895980                     40.0                   86.7
# 334965      334966                     40.0                   92.3
# 2895          2896                     40.0                   75.7
# 779223      779224                     40.0                   76.1
# 963524      963525                     40.0                   88.7
#
#         class_participation  total_score grade
# 895979                  6.7        100.0     A
# 334965                  5.4        100.0     A
# 2895                    4.2        100.0     A
# 779223                  6.4        100.0     A
# 963524                  7.0        100.0     A

# %%
std =df[df['attendance_percentage'] ==  df['attendance_percentage'].max()].count()['student_id']
per =std*100/total 
per
# Out:
# 6.7378

# %%
total =df.shape[0]
total
# Out:
# 1000000

# %%
df.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A

# %%
std1 =df[df['class_participation'] ==  df['class_participation'].max()].count()['student_id']
per =std1*100/total  
per
# Out:
# 2.4128

# %%
def scorelev(s): 
    if s>=90: 
        return 'High'
    elif s>=70:
        return 'Medium'
    else: 
        return 'Low' 

df['Scoring_level'] =df['total_score'].apply(scorelev)

# %%
df.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade Scoring_level
# 0                  3.8         97.9     A          High
# 1                  2.5         83.9     B        Medium
# 2                  5.3        100.0     A          High
# 3                  7.0        100.0     A          High
# 4                  6.9         92.0     A          High

# %%
df[df['total_score'] ==  df['total_score'].max()]
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 6                7                     26.1                   81.8
# 17              18                     17.2                   74.0
# 20              21                     25.3                   89.3
# ...            ...                      ...                    ...
# 999991      999992                     30.0                   87.4
# 999992      999993                     26.3                   84.6
# 999995      999996                     18.0                   95.5
# 999998      999999                     25.3                   90.0
# 999999     1000000                     18.3                   84.6
#
#         class_participation  total_score grade Scoring_level
# 2                       5.3        100.0     A          High
# 3                       7.0        100.0     A          High
# 6                       5.9        100.0     A          High
# 17                      8.1        100.0     A          High
# 20                      6.4        100.0     A          High
# ...                     ...          ...   ...           ...
# 999991                  6.7        100.0     A          High
# 999992                  4.5        100.0     A          High
# 999995                  4.8        100.0     A          High
# 999998                  5.3        100.0     A          High
# 999999                  4.1        100.0     A          High
#
# [268121 rows x 7 columns]

# %%
len(df[df['total_score'] ==  df['total_score'].max()])
# Out:
# 268121

# %%
df['Efficiency'] =df['total_score']/df['weekly_self_study_hours']

# %%
df.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade Scoring_level  Efficiency
# 0                  3.8         97.9     A          High    5.291892
# 1                  2.5         83.9     B        Medium    5.992857
# 2                  5.3        100.0     A          High    5.128205
# 3                  7.0        100.0     A          High    3.891051
# 4                  6.9         92.0     A          High    6.865672

# %%
def cat(x):
    if x<10:
        return 'light'
    elif x<=20:
        return 'Moderate'
    else: 
        return 'heavy'

df['Category'] =df['weekly_self_study_hours'].apply(cat)

# %%
df.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade Scoring_level  Efficiency  Category
# 0                  3.8         97.9     A          High    5.291892  Moderate
# 1                  2.5         83.9     B        Medium    5.992857  Moderate
# 2                  5.3        100.0     A          High    5.128205  Moderate
# 3                  7.0        100.0     A          High    3.891051     heavy
# 4                  6.9         92.0     A          High    6.865672  Moderate
